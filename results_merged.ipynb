# %% [markdown]
# # Results with Merged Dataset
# Remember to use your new dataset, `combined_dataset.csv`

# %%
# load dataset
import pandas as pd
df = pd.read_csv('combined_dataset.csv')
df.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 1  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 2    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 3    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 4    AUDI A3         2.0         4    Auto-S6        2WD  Gasoline
#
#   veh_class_2008  air_pollut_2008  city_mpg_2008  hwy_mpg_2008   ...     \
# 0            SUV              7.0           19.0          27.0   ...
# 1            SUV              7.0           19.0          27.0   ...
# 2  station wagon              7.0           24.0          33.0   ...
# 3  station wagon              7.0           24.0          33.0   ...
# 4  station wagon              7.0           27.0          37.0   ...
#
#         trans  drive      fuel  veh_class  air_pollution_score  city_mpg  \
# ...

# %% [markdown]
# ### Q5: For all of the models that were produced in 2008 that are still being produced now, how much has the mpg improved and which vehicle improved the most?

# %%
df_modelmpg8 = df.groupby('model_2008').mean().cmb_mpg_2008
df_modelmpg8
# Out:
# model_2008
# ACURA RDX                      22.000000
# AUDI A3                        28.333333
# AUDI A4                        27.250000
# AUDI A6                        22.666667
# AUDI A8 L                      21.500000
# AUDI Q7                        24.500000
# AUDI S4                        24.000000
# AUDI S5                        11.000000
# AUDI TT Coupe                  27.333333
# AUDI TT Roadster               27.333333
# BMW 750i                       19.000000
# BMW Alpina B7                  20.000000
# BMW M6 Convertible             16.500000
# CADILLAC CTS                   22.000000
# CADILLAC Escalade              23.000000
# CHEVROLET Corvette             15.000000
# CHEVROLET Equinox              18.500000
# CHEVROLET Impala               34.000000
# CHEVROLET Malibu               28.333333
# CHEVROLET Silverado 15         28.500000
# CHEVROLET Tahoe 1500           24.000000
# CHRYSLER 300                   28.600000
# ...

# %%
df_modelmpg18 = df.groupby('model').mean().cmb_mpg
df_modelmpg18
# Out:
# model
# ACURA RDX                      22.500000
# AUDI A3                        28.000000
# AUDI A4                        27.000000
# AUDI A6                        25.666667
# AUDI A8 L                      22.000000
# AUDI Q7                        21.000000
# AUDI S4                        24.000000
# AUDI S5                        24.000000
# AUDI TT Coupe                  26.000000
# AUDI TT Roadster               26.000000
# BMW 750i                       19.500000
# BMW Alpina B7                  19.000000
# BMW M6 Convertible             16.500000
# CADILLAC CTS                   22.800000
# CADILLAC Escalade              17.000000
# CHEVROLET Corvette             17.750000
# CHEVROLET Equinox              27.833333
# CHEVROLET Impala               21.250000
# CHEVROLET Malibu               33.000000
# CHEVROLET Silverado 15         17.312500
# CHEVROLET Tahoe 1500           16.875000
# CHRYSLER 300                   20.000000
# CHRYSLER Pacifica              22.000000
# ...

# %%
df['mpg_change'] = df_modelmpg8.sub(df_modelmpg18, fill_value=0)
df.head()
df['mpg_change']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
#        ..
# 892   NaN
# 893   NaN
# 894   NaN
# 895   NaN
# 896   NaN
# 897   NaN
# 898   NaN
# 899   NaN
# 900   NaN
# 901   NaN
# 902   NaN
# 903   NaN
# 904   NaN
# 905   NaN
# 906   NaN
# 907   NaN
# 908   NaN
# 909   NaN
# 910   NaN
# 911   NaN
# 912   NaN
# 913   NaN
# 914   NaN
# 915   NaN
# 916   NaN
# 917   NaN
# 918   NaN
# 919   NaN
# 920   NaN
# 921   NaN
# Name: mpg_change, Length: 922, dtype: float64
